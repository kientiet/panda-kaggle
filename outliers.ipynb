# %% [markdown]
# # Import package

# %%
import os
import torch
import pandas as pd
import numpy as np
import pytorch_lightning as pl
from pytorch_lightning import loggers
from pytorch_lightning.callbacks import ModelCheckpoint

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Setup environment

# %%
device = "cuda" if torch.cuda.is_available else "cpu"

def format_bytes(size):
    # 2**10 = 1024
    power = 2**10
    n = 0
    power_labels = {0 : '', 1: 'kilo', 2: 'mega', 3: 'giga', 4: 'tera'}
    while size > power:
        size /= power
        n += 1
    return "%.2f" % size, power_labels[n] + 'bytes'

torch.cuda.get_device_name(), format_bytes(torch.cuda.get_device_properties(device).total_memory)
# Out:
# ('GeForce GTX 1080 Ti', ('10.92', 'gigabytes'))

# %% [markdown]
# # Load model

# %%
from trainer.distill.outliers import OutliersTrainer
model = OutliersTrainer()
max_epoches = model.get_max_epoches()
# Out:
# >> Load from data frame
#
#
# >> The transformation of student is
# <function apply_policy at 0x7fcc51b0d820>
# >> Return trainloader
# >> Return valloader
# Using cache found in /home/kientiet/.cache/torch/hub/facebookresearch_semi-supervised-ImageNet1K-models_master
# >> Load from data frame
# Using cache found in /home/kientiet/.cache/torch/hub/facebookresearch_semi-supervised-ImageNet1K-models_master
# >> Running with 1cycle scheduler
#
#
# >> Running with 1cycle scheduler

# %%
import torchvision
import matplotlib.pyplot as plt
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
plt.figure(figsize=(20,40))
images, labels = next(iter(model.trainloader))
images = images.reshape(-1, 3, 128, 128)
# show images
imshow(torchvision.utils.make_grid(images))

# %%
checkpoint_path = os.path.join(os.getcwd(), "checkpoint", model.model_name)
checkpoint_callback = ModelCheckpoint(
    filepath = checkpoint_path,
    save_top_k = 5,
    verbose = True,
    monitor = 'kappa_score/kappa_score',
    mode = 'max'
)

checkpoint_path
# Out:
# '/home/kientiet/Documents/My Project/python/panda-kaggle/checkpoint/outliers/resnet50_32x4d'

# %%
tb_logger = loggers.TensorBoardLogger('logs/', name = model.model_name)
trainer = pl.Trainer(checkpoint_callback = checkpoint_callback,
                    nb_sanity_val_steps = 0, 
                    max_epochs = max_epoches, 
                    gpus = -1, 
                    logger = tb_logger)
# Out:
# INFO:lightning:GPU available: True, used: True
# INFO:lightning:CUDA_VISIBLE_DEVICES: [0]

# %% [markdown]
# # Learning finder

# %%
# lr_finder = trainer.lr_find(model, min_lr = 1e-8, max_lr = 5., num_training = 200)

# %%
# fig = lr_finder.plot(suggest = True)

# %%
model.configure_optimizers()
# Out:
# >> Running with 1cycle scheduler
# Lookahead (
# Parameter Group 0
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     initial_lr: 0.0005
#     lr: 0.0004999997256657939
#     max_lr: 0.0005
#     min_lr: 5e-06
#     step_counter: 0
#     weight_decay: 5e-05
# )

# %% [markdown]
# ## Start to train

# %%
trainer.fit(model)
# Out:
# INFO:lightning:
#     | Name                                     | Type              | Params
# ---------------------------------------------------------------------------
# 0   | encoder                                  | ResNetModel       | 22 M
# 1   | encoder.encoder                          | Sequential        | 22 M
# 2   | encoder.encoder.0                        | Conv2d            | 9 K
# 3   | encoder.encoder.1                        | BatchNorm2d       | 128
# 4   | encoder.encoder.2                        | ReLU              | 0
# 5   | encoder.encoder.3                        | MaxPool2d         | 0
# 6   | encoder.encoder.4                        | Sequential        | 205 K
# 7   | encoder.encoder.4.0                      | Bottleneck        | 63 K
# 8   | encoder.encoder.4.0.conv1                | Conv2d            | 8 K
# 9   | encoder.encoder.4.0.bn1                  | BatchNorm2d       | 256
# 10  | encoder.encoder.4.0.conv2                | Conv2d            | 4 K
# 11  | encoder.encoder.4.0.bn2                  | BatchNorm2d       | 256
# 12  | encoder.encoder.4.0.conv3                | Conv2d            | 32 K
# 13  | encoder.encoder.4.0.bn3                  | BatchNorm2d       | 512
# 14  | encoder.encoder.4.0.relu                 | ReLU              | 0
# 15  | encoder.encoder.4.0.downsample           | Sequential        | 16 K
# 16  | encoder.encoder.4.0.downsample.0         | Conv2d            | 16 K
# 17  | encoder.encoder.4.0.downsample.1         | BatchNorm2d       | 512
# 18  | encoder.encoder.4.1                      | Bottleneck        | 71 K
# 19  | encoder.encoder.4.1.conv1                | Conv2d            | 32 K
# 20  | encoder.encoder.4.1.bn1                  | BatchNorm2d       | 256
# 21  | encoder.encoder.4.1.conv2                | Conv2d            | 4 K
# 22  | encoder.encoder.4.1.bn2                  | BatchNorm2d       | 256
# 23  | encoder.encoder.4.1.conv3                | Conv2d            | 32 K
# 24  | encoder.encoder.4.1.bn3                  | BatchNorm2d       | 512
# 25  | encoder.encoder.4.1.relu                 | ReLU              | 0
# 26  | encoder.encoder.4.2                      | Bottleneck        | 71 K
# 27  | encoder.encoder.4.2.conv1                | Conv2d            | 32 K
# 28  | encoder.encoder.4.2.bn1                  | BatchNorm2d       | 256
# 29  | encoder.encoder.4.2.conv2                | Conv2d            | 4 K
# 30  | encoder.encoder.4.2.bn2                  | BatchNorm2d       | 256
# 31  | encoder.encoder.4.2.conv3                | Conv2d            | 32 K
# 32  | encoder.encoder.4.2.bn3                  | BatchNorm2d       | 512
# 33  | encoder.encoder.4.2.relu                 | ReLU              | 0
# 34  | encoder.encoder.5                        | Sequential        | 1 M
# 35  | encoder.encoder.5.0                      | Bottleneck        | 349 K
# 36  | encoder.encoder.5.0.conv1                | Conv2d            | 65 K
# 37  | encoder.encoder.5.0.bn1                  | BatchNorm2d       | 512
# 38  | encoder.encoder.5.0.conv2                | Conv2d            | 18 K
# 39  | encoder.encoder.5.0.bn2                  | BatchNorm2d       | 512
# 40  | encoder.encoder.5.0.conv3                | Conv2d            | 131 K
# 41  | encoder.encoder.5.0.bn3                  | BatchNorm2d       | 1 K
# 42  | encoder.encoder.5.0.relu                 | ReLU              | 0
# 43  | encoder.encoder.5.0.downsample           | Sequential        | 132 K
# 44  | encoder.encoder.5.0.downsample.0         | Conv2d            | 131 K
# 45  | encoder.encoder.5.0.downsample.1         | BatchNorm2d       | 1 K
# 46  | encoder.encoder.5.1                      | Bottleneck        | 282 K
# 47  | encoder.encoder.5.1.conv1                | Conv2d            | 131 K
# 48  | encoder.encoder.5.1.bn1                  | BatchNorm2d       | 512
# 49  | encoder.encoder.5.1.conv2                | Conv2d            | 18 K
# 50  | encoder.encoder.5.1.bn2                  | BatchNorm2d       | 512
# 51  | encoder.encoder.5.1.conv3                | Conv2d            | 131 K
# 52  | encoder.encoder.5.1.bn3                  | BatchNorm2d       | 1 K
# 53  | encoder.encoder.5.1.relu                 | ReLU              | 0
# 54  | encoder.encoder.5.2                      | Bottleneck        | 282 K
# 55  | encoder.encoder.5.2.conv1                | Conv2d            | 131 K
# 56  | encoder.encoder.5.2.bn1                  | BatchNorm2d       | 512
# 57  | encoder.encoder.5.2.conv2                | Conv2d            | 18 K
# 58  | encoder.encoder.5.2.bn2                  | BatchNorm2d       | 512
# 59  | encoder.encoder.5.2.conv3                | Conv2d            | 131 K
# 60  | encoder.encoder.5.2.bn3                  | BatchNorm2d       | 1 K
# 61  | encoder.encoder.5.2.relu                 | ReLU              | 0
# 62  | encoder.encoder.5.3                      | Bottleneck        | 282 K
# 63  | encoder.encoder.5.3.conv1                | Conv2d            | 131 K
# 64  | encoder.encoder.5.3.bn1                  | BatchNorm2d       | 512
# 65  | encoder.encoder.5.3.conv2                | Conv2d            | 18 K
# 66  | encoder.encoder.5.3.bn2                  | BatchNorm2d       | 512
# 67  | encoder.encoder.5.3.conv3                | Conv2d            | 131 K
# 68  | encoder.encoder.5.3.bn3                  | BatchNorm2d       | 1 K
# 69  | encoder.encoder.5.3.relu                 | ReLU              | 0
# 70  | encoder.encoder.6                        | Sequential        | 7 M
# 71  | encoder.encoder.6.0                      | Bottleneck        | 1 M
# 72  | encoder.encoder.6.0.conv1                | Conv2d            | 262 K
# 73  | encoder.encoder.6.0.bn1                  | BatchNorm2d       | 1 K
# 74  | encoder.encoder.6.0.conv2                | Conv2d            | 73 K
# 75  | encoder.encoder.6.0.bn2                  | BatchNorm2d       | 1 K
# 76  | encoder.encoder.6.0.conv3                | Conv2d            | 524 K
# 77  | encoder.encoder.6.0.bn3                  | BatchNorm2d       | 2 K
# 78  | encoder.encoder.6.0.relu                 | ReLU              | 0
# 79  | encoder.encoder.6.0.downsample           | Sequential        | 526 K
# 80  | encoder.encoder.6.0.downsample.0         | Conv2d            | 524 K
# 81  | encoder.encoder.6.0.downsample.1         | BatchNorm2d       | 2 K
# 82  | encoder.encoder.6.1                      | Bottleneck        | 1 M
# 83  | encoder.encoder.6.1.conv1                | Conv2d            | 524 K
# 84  | encoder.encoder.6.1.bn1                  | BatchNorm2d       | 1 K
# 85  | encoder.encoder.6.1.conv2                | Conv2d            | 73 K
# 86  | encoder.encoder.6.1.bn2                  | BatchNorm2d       | 1 K
# 87  | encoder.encoder.6.1.conv3                | Conv2d            | 524 K
# 88  | encoder.encoder.6.1.bn3                  | BatchNorm2d       | 2 K
# 89  | encoder.encoder.6.1.relu                 | ReLU              | 0
# 90  | encoder.encoder.6.2                      | Bottleneck        | 1 M
# 91  | encoder.encoder.6.2.conv1                | Conv2d            | 524 K
# 92  | encoder.encoder.6.2.bn1                  | BatchNorm2d       | 1 K
# 93  | encoder.encoder.6.2.conv2                | Conv2d            | 73 K
# 94  | encoder.encoder.6.2.bn2                  | BatchNorm2d       | 1 K
# 95  | encoder.encoder.6.2.conv3                | Conv2d            | 524 K
# 96  | encoder.encoder.6.2.bn3                  | BatchNorm2d       | 2 K
# 97  | encoder.encoder.6.2.relu                 | ReLU              | 0
# 98  | encoder.encoder.6.3                      | Bottleneck        | 1 M
# 99  | encoder.encoder.6.3.conv1                | Conv2d            | 524 K
# 100 | encoder.encoder.6.3.bn1                  | BatchNorm2d       | 1 K
# 101 | encoder.encoder.6.3.conv2                | Conv2d            | 73 K
# 102 | encoder.encoder.6.3.bn2                  | BatchNorm2d       | 1 K
# 103 | encoder.encoder.6.3.conv3                | Conv2d            | 524 K
# 104 | encoder.encoder.6.3.bn3                  | BatchNorm2d       | 2 K
# 105 | encoder.encoder.6.3.relu                 | ReLU              | 0
# 106 | encoder.encoder.6.4                      | Bottleneck        | 1 M
# 107 | encoder.encoder.6.4.conv1                | Conv2d            | 524 K
# 108 | encoder.encoder.6.4.bn1                  | BatchNorm2d       | 1 K
# 109 | encoder.encoder.6.4.conv2                | Conv2d            | 73 K
# 110 | encoder.encoder.6.4.bn2                  | BatchNorm2d       | 1 K
# 111 | encoder.encoder.6.4.conv3                | Conv2d            | 524 K
# 112 | encoder.encoder.6.4.bn3                  | BatchNorm2d       | 2 K
# 113 | encoder.encoder.6.4.relu                 | ReLU              | 0
# 114 | encoder.encoder.6.5                      | Bottleneck        | 1 M
# 115 | encoder.encoder.6.5.conv1                | Conv2d            | 524 K
# 116 | encoder.encoder.6.5.bn1                  | BatchNorm2d       | 1 K
# 117 | encoder.encoder.6.5.conv2                | Conv2d            | 73 K
# 118 | encoder.encoder.6.5.bn2                  | BatchNorm2d       | 1 K
# 119 | encoder.encoder.6.5.conv3                | Conv2d            | 524 K
# 120 | encoder.encoder.6.5.bn3                  | BatchNorm2d       | 2 K
# 121 | encoder.encoder.6.5.relu                 | ReLU              | 0
# 122 | encoder.encoder.7                        | Sequential        | 14 M
# 123 | encoder.encoder.7.0                      | Bottleneck        | 5 M
# 124 | encoder.encoder.7.0.conv1                | Conv2d            | 1 M
# 125 | encoder.encoder.7.0.bn1                  | BatchNorm2d       | 2 K
# 126 | encoder.encoder.7.0.conv2                | Conv2d            | 294 K
# 127 | encoder.encoder.7.0.bn2                  | BatchNorm2d       | 2 K
# 128 | encoder.encoder.7.0.conv3                | Conv2d            | 2 M
# 129 | encoder.encoder.7.0.bn3                  | BatchNorm2d       | 4 K
# 130 | encoder.encoder.7.0.relu                 | ReLU              | 0
# 131 | encoder.encoder.7.0.downsample           | Sequential        | 2 M
# 132 | encoder.encoder.7.0.downsample.0         | Conv2d            | 2 M
# 133 | encoder.encoder.7.0.downsample.1         | BatchNorm2d       | 4 K
# 134 | encoder.encoder.7.1                      | Bottleneck        | 4 M
# 135 | encoder.encoder.7.1.conv1                | Conv2d            | 2 M
# 136 | encoder.encoder.7.1.bn1                  | BatchNorm2d       | 2 K
# 137 | encoder.encoder.7.1.conv2                | Conv2d            | 294 K
# 138 | encoder.encoder.7.1.bn2                  | BatchNorm2d       | 2 K
# 139 | encoder.encoder.7.1.conv3                | Conv2d            | 2 M
# 140 | encoder.encoder.7.1.bn3                  | BatchNorm2d       | 4 K
# 141 | encoder.encoder.7.1.relu                 | ReLU              | 0
# 142 | encoder.encoder.7.2                      | Bottleneck        | 4 M
# 143 | encoder.encoder.7.2.conv1                | Conv2d            | 2 M
# 144 | encoder.encoder.7.2.bn1                  | BatchNorm2d       | 2 K
# 145 | encoder.encoder.7.2.conv2                | Conv2d            | 294 K
# 146 | encoder.encoder.7.2.bn2                  | BatchNorm2d       | 2 K
# 147 | encoder.encoder.7.2.conv3                | Conv2d            | 2 M
# 148 | encoder.encoder.7.2.bn3                  | BatchNorm2d       | 4 K
# 149 | encoder.encoder.7.2.relu                 | ReLU              | 0
# 150 | project_layer                            | ProjectLayer      | 2 M
# 151 | project_layer.avg_pooling                | AdaptiveAvgPool2d | 0
# 152 | project_layer.max_pooling                | AdaptiveMaxPool2d | 0
# 153 | project_layer.head                       | Sequential        | 2 M
# 154 | project_layer.head.0                     | Flatten           | 0
# 155 | project_layer.head.1                     | Linear            | 2 M
# 156 | project_layer.head.2                     | Mish              | 0
# 157 | project_layer.head.3                     | BatchNorm1d       | 1 K
# 158 | project_layer.head.4                     | Dropout           | 0
# 159 | project_layer.head.5                     | Linear            | 3 K
# 160 | teacher                                  | BaselineTrainer   | 25 M
# 161 | teacher.loss_func                        | CrossEntropyLoss  | 0
# 162 | teacher.encoder                          | ResNetModel       | 22 M
# 163 | teacher.encoder.encoder                  | Sequential        | 22 M
# 164 | teacher.encoder.encoder.0                | Conv2d            | 9 K
# 165 | teacher.encoder.encoder.1                | BatchNorm2d       | 128
# 166 | teacher.encoder.encoder.2                | ReLU              | 0
# 167 | teacher.encoder.encoder.3                | MaxPool2d         | 0
# 168 | teacher.encoder.encoder.4                | Sequential        | 205 K
# 169 | teacher.encoder.encoder.4.0              | Bottleneck        | 63 K
# 170 | teacher.encoder.encoder.4.0.conv1        | Conv2d            | 8 K
# 171 | teacher.encoder.encoder.4.0.bn1          | BatchNorm2d       | 256
# 172 | teacher.encoder.encoder.4.0.conv2        | Conv2d            | 4 K
# 173 | teacher.encoder.encoder.4.0.bn2          | BatchNorm2d       | 256
# 174 | teacher.encoder.encoder.4.0.conv3        | Conv2d            | 32 K
# 175 | teacher.encoder.encoder.4.0.bn3          | BatchNorm2d       | 512
# 176 | teacher.encoder.encoder.4.0.relu         | ReLU              | 0
# 177 | teacher.encoder.encoder.4.0.downsample   | Sequential        | 16 K
# 178 | teacher.encoder.encoder.4.0.downsample.0 | Conv2d            | 16 K
# 179 | teacher.encoder.encoder.4.0.downsample.1 | BatchNorm2d       | 512
# 180 | teacher.encoder.encoder.4.1              | Bottleneck        | 71 K
# 181 | teacher.encoder.encoder.4.1.conv1        | Conv2d            | 32 K
# 182 | teacher.encoder.encoder.4.1.bn1          | BatchNorm2d       | 256
# 183 | teacher.encoder.encoder.4.1.conv2        | Conv2d            | 4 K
# 184 | teacher.encoder.encoder.4.1.bn2          | BatchNorm2d       | 256
# 185 | teacher.encoder.encoder.4.1.conv3        | Conv2d            | 32 K
# 186 | teacher.encoder.encoder.4.1.bn3          | BatchNorm2d       | 512
# 187 | teacher.encoder.encoder.4.1.relu         | ReLU              | 0
# 188 | teacher.encoder.encoder.4.2              | Bottleneck        | 71 K
# 189 | teacher.encoder.encoder.4.2.conv1        | Conv2d            | 32 K
# 190 | teacher.encoder.encoder.4.2.bn1          | BatchNorm2d       | 256
# 191 | teacher.encoder.encoder.4.2.conv2        | Conv2d            | 4 K
# 192 | teacher.encoder.encoder.4.2.bn2          | BatchNorm2d       | 256
# 193 | teacher.encoder.encoder.4.2.conv3        | Conv2d            | 32 K
# 194 | teacher.encoder.encoder.4.2.bn3          | BatchNorm2d       | 512
# 195 | teacher.encoder.encoder.4.2.relu         | ReLU              | 0
# 196 | teacher.encoder.encoder.5                | Sequential        | 1 M
# 197 | teacher.encoder.encoder.5.0              | Bottleneck        | 349 K
# 198 | teacher.encoder.encoder.5.0.conv1        | Conv2d            | 65 K
# 199 | teacher.encoder.encoder.5.0.bn1          | BatchNorm2d       | 512
# 200 | teacher.encoder.encoder.5.0.conv2        | Conv2d            | 18 K
# 201 | teacher.encoder.encoder.5.0.bn2          | BatchNorm2d       | 512
# 202 | teacher.encoder.encoder.5.0.conv3        | Conv2d            | 131 K
# 203 | teacher.encoder.encoder.5.0.bn3          | BatchNorm2d       | 1 K
# 204 | teacher.encoder.encoder.5.0.relu         | ReLU              | 0
# 205 | teacher.encoder.encoder.5.0.downsample   | Sequential        | 132 K
# 206 | teacher.encoder.encoder.5.0.downsample.0 | Conv2d            | 131 K
# 207 | teacher.encoder.encoder.5.0.downsample.1 | BatchNorm2d       | 1 K
# 208 | teacher.encoder.encoder.5.1              | Bottleneck        | 282 K
# 209 | teacher.encoder.encoder.5.1.conv1        | Conv2d            | 131 K
# 210 | teacher.encoder.encoder.5.1.bn1          | BatchNorm2d       | 512
# 211 | teacher.encoder.encoder.5.1.conv2        | Conv2d            | 18 K
# 212 | teacher.encoder.encoder.5.1.bn2          | BatchNorm2d       | 512
# 213 | teacher.encoder.encoder.5.1.conv3        | Conv2d            | 131 K
# 214 | teacher.encoder.encoder.5.1.bn3          | BatchNorm2d       | 1 K
# 215 | teacher.encoder.encoder.5.1.relu         | ReLU              | 0
# 216 | teacher.encoder.encoder.5.2              | Bottleneck        | 282 K
# 217 | teacher.encoder.encoder.5.2.conv1        | Conv2d            | 131 K
# 218 | teacher.encoder.encoder.5.2.bn1          | BatchNorm2d       | 512
# 219 | teacher.encoder.encoder.5.2.conv2        | Conv2d            | 18 K
# 220 | teacher.encoder.encoder.5.2.bn2          | BatchNorm2d       | 512
# 221 | teacher.encoder.encoder.5.2.conv3        | Conv2d            | 131 K
# 222 | teacher.encoder.encoder.5.2.bn3          | BatchNorm2d       | 1 K
# 223 | teacher.encoder.encoder.5.2.relu         | ReLU              | 0
# 224 | teacher.encoder.encoder.5.3              | Bottleneck        | 282 K
# 225 | teacher.encoder.encoder.5.3.conv1        | Conv2d            | 131 K
# 226 | teacher.encoder.encoder.5.3.bn1          | BatchNorm2d       | 512
# 227 | teacher.encoder.encoder.5.3.conv2        | Conv2d            | 18 K
# 228 | teacher.encoder.encoder.5.3.bn2          | BatchNorm2d       | 512
# 229 | teacher.encoder.encoder.5.3.conv3        | Conv2d            | 131 K
# 230 | teacher.encoder.encoder.5.3.bn3          | BatchNorm2d       | 1 K
# 231 | teacher.encoder.encoder.5.3.relu         | ReLU              | 0
# 232 | teacher.encoder.encoder.6                | Sequential        | 7 M
# 233 | teacher.encoder.encoder.6.0              | Bottleneck        | 1 M
# 234 | teacher.encoder.encoder.6.0.conv1        | Conv2d            | 262 K
# 235 | teacher.encoder.encoder.6.0.bn1          | BatchNorm2d       | 1 K
# 236 | teacher.encoder.encoder.6.0.conv2        | Conv2d            | 73 K
# 237 | teacher.encoder.encoder.6.0.bn2          | BatchNorm2d       | 1 K
# 238 | teacher.encoder.encoder.6.0.conv3        | Conv2d            | 524 K
# 239 | teacher.encoder.encoder.6.0.bn3          | BatchNorm2d       | 2 K
# 240 | teacher.encoder.encoder.6.0.relu         | ReLU              | 0
# 241 | teacher.encoder.encoder.6.0.downsample   | Sequential        | 526 K
# 242 | teacher.encoder.encoder.6.0.downsample.0 | Conv2d            | 524 K
# 243 | teacher.encoder.encoder.6.0.downsample.1 | BatchNorm2d       | 2 K
# 244 | teacher.encoder.encoder.6.1              | Bottleneck        | 1 M
# 245 | teacher.encoder.encoder.6.1.conv1        | Conv2d            | 524 K
# 246 | teacher.encoder.encoder.6.1.bn1          | BatchNorm2d       | 1 K
# 247 | teacher.encoder.encoder.6.1.conv2        | Conv2d            | 73 K
# 248 | teacher.encoder.encoder.6.1.bn2          | BatchNorm2d       | 1 K
# 249 | teacher.encoder.encoder.6.1.conv3        | Conv2d            | 524 K
# 250 | teacher.encoder.encoder.6.1.bn3          | BatchNorm2d       | 2 K
# 251 | teacher.encoder.encoder.6.1.relu         | ReLU              | 0
# 252 | teacher.encoder.encoder.6.2              | Bottleneck        | 1 M
# 253 | teacher.encoder.encoder.6.2.conv1        | Conv2d            | 524 K
# 254 | teacher.encoder.encoder.6.2.bn1          | BatchNorm2d       | 1 K
# 255 | teacher.encoder.encoder.6.2.conv2        | Conv2d            | 73 K
# 256 | teacher.encoder.encoder.6.2.bn2          | BatchNorm2d       | 1 K
# 257 | teacher.encoder.encoder.6.2.conv3        | Conv2d            | 524 K
# 258 | teacher.encoder.encoder.6.2.bn3          | BatchNorm2d       | 2 K
# 259 | teacher.encoder.encoder.6.2.relu         | ReLU              | 0
# 260 | teacher.encoder.encoder.6.3              | Bottleneck        | 1 M
# 261 | teacher.encoder.encoder.6.3.conv1        | Conv2d            | 524 K
# 262 | teacher.encoder.encoder.6.3.bn1          | BatchNorm2d       | 1 K
# 263 | teacher.encoder.encoder.6.3.conv2        | Conv2d            | 73 K
# 264 | teacher.encoder.encoder.6.3.bn2          | BatchNorm2d       | 1 K
# 265 | teacher.encoder.encoder.6.3.conv3        | Conv2d            | 524 K
# 266 | teacher.encoder.encoder.6.3.bn3          | BatchNorm2d       | 2 K
# 267 | teacher.encoder.encoder.6.3.relu         | ReLU              | 0
# 268 | teacher.encoder.encoder.6.4              | Bottleneck        | 1 M
# 269 | teacher.encoder.encoder.6.4.conv1        | Conv2d            | 524 K
# 270 | teacher.encoder.encoder.6.4.bn1          | BatchNorm2d       | 1 K
# 271 | teacher.encoder.encoder.6.4.conv2        | Conv2d            | 73 K
# 272 | teacher.encoder.encoder.6.4.bn2          | BatchNorm2d       | 1 K
# 273 | teacher.encoder.encoder.6.4.conv3        | Conv2d            | 524 K
# 274 | teacher.encoder.encoder.6.4.bn3          | BatchNorm2d       | 2 K
# 275 | teacher.encoder.encoder.6.4.relu         | ReLU              | 0
# 276 | teacher.encoder.encoder.6.5              | Bottleneck        | 1 M
# 277 | teacher.encoder.encoder.6.5.conv1        | Conv2d            | 524 K
# 278 | teacher.encoder.encoder.6.5.bn1          | BatchNorm2d       | 1 K
# 279 | teacher.encoder.encoder.6.5.conv2        | Conv2d            | 73 K
# 280 | teacher.encoder.encoder.6.5.bn2          | BatchNorm2d       | 1 K
# 281 | teacher.encoder.encoder.6.5.conv3        | Conv2d            | 524 K
# 282 | teacher.encoder.encoder.6.5.bn3          | BatchNorm2d       | 2 K
# 283 | teacher.encoder.encoder.6.5.relu         | ReLU              | 0
# 284 | teacher.encoder.encoder.7                | Sequential        | 14 M
# 285 | teacher.encoder.encoder.7.0              | Bottleneck        | 5 M
# 286 | teacher.encoder.encoder.7.0.conv1        | Conv2d            | 1 M
# 287 | teacher.encoder.encoder.7.0.bn1          | BatchNorm2d       | 2 K
# 288 | teacher.encoder.encoder.7.0.conv2        | Conv2d            | 294 K
# 289 | teacher.encoder.encoder.7.0.bn2          | BatchNorm2d       | 2 K
# 290 | teacher.encoder.encoder.7.0.conv3        | Conv2d            | 2 M
# 291 | teacher.encoder.encoder.7.0.bn3          | BatchNorm2d       | 4 K
# 292 | teacher.encoder.encoder.7.0.relu         | ReLU              | 0
# 293 | teacher.encoder.encoder.7.0.downsample   | Sequential        | 2 M
# 294 | teacher.encoder.encoder.7.0.downsample.0 | Conv2d            | 2 M
# 295 | teacher.encoder.encoder.7.0.downsample.1 | BatchNorm2d       | 4 K
# 296 | teacher.encoder.encoder.7.1              | Bottleneck        | 4 M
# 297 | teacher.encoder.encoder.7.1.conv1        | Conv2d            | 2 M
# 298 | teacher.encoder.encoder.7.1.bn1          | BatchNorm2d       | 2 K
# 299 | teacher.encoder.encoder.7.1.conv2        | Conv2d            | 294 K
# 300 | teacher.encoder.encoder.7.1.bn2          | BatchNorm2d       | 2 K
# 301 | teacher.encoder.encoder.7.1.conv3        | Conv2d            | 2 M
# 302 | teacher.encoder.encoder.7.1.bn3          | BatchNorm2d       | 4 K
# 303 | teacher.encoder.encoder.7.1.relu         | ReLU              | 0
# 304 | teacher.encoder.encoder.7.2              | Bottleneck        | 4 M
# 305 | teacher.encoder.encoder.7.2.conv1        | Conv2d            | 2 M
# 306 | teacher.encoder.encoder.7.2.bn1          | BatchNorm2d       | 2 K
# 307 | teacher.encoder.encoder.7.2.conv2        | Conv2d            | 294 K
# 308 | teacher.encoder.encoder.7.2.bn2          | BatchNorm2d       | 2 K
# 309 | teacher.encoder.encoder.7.2.conv3        | Conv2d            | 2 M
# 310 | teacher.encoder.encoder.7.2.bn3          | BatchNorm2d       | 4 K
# 311 | teacher.encoder.encoder.7.2.relu         | ReLU              | 0
# 312 | teacher.project_layer                    | ProjectLayer      | 2 M
# 313 | teacher.project_layer.avg_pooling        | AdaptiveAvgPool2d | 0
# 314 | teacher.project_layer.max_pooling        | AdaptiveMaxPool2d | 0
# 315 | teacher.project_layer.head               | Sequential        | 2 M
# 316 | teacher.project_layer.head.0             | Flatten           | 0
# 317 | teacher.project_layer.head.1             | Linear            | 2 M
# 318 | teacher.project_layer.head.2             | Mish              | 0
# 319 | teacher.project_layer.head.3             | BatchNorm1d       | 1 K
# 320 | teacher.project_layer.head.4             | Dropout           | 0
# 321 | teacher.project_layer.head.5             | Linear            | 3 K
# 322 | loss_func                                | OutliersLoss      | 0
# 323 | loss_func.cross_entropy                  | CrossEntropyLoss  | 0
# 324 | loss_func.kl_loss                        | KLDivLoss         | 0
# >> Running with 1cycle scheduler
# >> Return trainloader
# >> Return valloader
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# /pytorch/torch/csrc/utils/python_arg_parser.cpp:756: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00000: kappa_score/kappa_score reached 0.39889 (best 0.39889), saving model to /home/kientiet/Documents/My Project/python/panda-kaggle/checkpoint/outliers/_ckpt_epoch_0_v0.ckpt as top 5
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00001: kappa_score/kappa_score reached 0.47870 (best 0.47870), saving model to /home/kientiet/Documents/My Project/python/panda-kaggle/checkpoint/outliers/_ckpt_epoch_1.ckpt as top 5
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00002: kappa_score/kappa_score reached 0.47407 (best 0.47870), saving model to /home/kientiet/Documents/My Project/python/panda-kaggle/checkpoint/outliers/_ckpt_epoch_2.ckpt as top 5
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00003: kappa_score/kappa_score reached 0.54838 (best 0.54838), saving model to /home/kientiet/Documents/My Project/python/panda-kaggle/checkpoint/outliers/_ckpt_epoch_3.ckpt as top 5
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00004: kappa_score/kappa_score reached 0.59672 (best 0.59672), saving model to /home/kientiet/Documents/My Project/python/panda-kaggle/checkpoint/outliers/_ckpt_epoch_4.ckpt as top 5
# >> Running with 1cycle scheduler
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00005: kappa_score/kappa_score  was not in top 5
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00006: kappa_score/kappa_score  was not in top 5
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00007: kappa_score/kappa_score reached 0.41270 (best 0.59672), saving model to /home/kientiet/Documents/My Project/python/panda-kaggle/checkpoint/outliers/_ckpt_epoch_7.ckpt as top 5
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00008: kappa_score/kappa_score reached 0.49048 (best 0.59672), saving model to /home/kientiet/Documents/My Project/python/panda-kaggle/checkpoint/outliers/_ckpt_epoch_8.ckpt as top 5
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00009: kappa_score/kappa_score reached 0.52676 (best 0.59672), saving model to /home/kientiet/Documents/My Project/python/panda-kaggle/checkpoint/outliers/_ckpt_epoch_9.ckpt as top 5
# >> Running with 1cycle scheduler
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00010: kappa_score/kappa_score  was not in top 5
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00011: kappa_score/kappa_score  was not in top 5
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00012: kappa_score/kappa_score  was not in top 5
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00013: kappa_score/kappa_score  was not in top 5
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# INFO:lightning:
# Epoch 00014: kappa_score/kappa_score  was not in top 5
# 1
